# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('./deeplearning.mplstyle')

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])

# %%
print(f"x_train: {x_train}, y_train: {y_train}")
# Out:
# x_train: [1. 2.]
# y_train: [300. 500.]

# %%
print(f"x_train shape: {x_train.shape}")
# Out:
# x_train shape: (2,)

# %%
m = x_train.shape[0]
print(f"Training examples: {m}")
# Out:
# Training examples: 2

# %%
m = len(x_train)
print(f"Training examples: {m}")
# Out:
# Training examples: 2

# %%
i = 0
x_i = x_train[i]
y_i = y_train[i]
print(f"{x_i}, {y_i}")
# Out:
# 1.0, 300.0

# %%
plt.scatter(x_train, y_train, marker='x', c='r')
plt.title("Housing Prices")
plt.xlabel("Size (1000 sqft)")
plt.ylabel("Price (in 1000s USD)")
# Out:
# Text(0, 0.5, 'Price (in 1000s USD)')

# %%
w = 100
b = 100
print(f"w: {w}, b: {b}")
# Out:
# w: 100, b: 100

# %%
def compute_output(x, w, b):
    m = x.shape[0]
    fx = np.zeros(m)
    for i in range(m):
        fx[i] = w * x[i] + b
    return fx

# %%
f_wb = compute_output(x_train, w, b,)

plt.plot(x_train, f_wb, c='b',label='Our Prediction')
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')
plt.title("Housing Prices")
plt.xlabel('Size (1000 sqft)')
plt.ylabel('Price (in 1000s USD)')
plt.legend()
plt.show()

# %%
w = 200
b = 100
print(f"w: {w}, b: {b}")
# Out:
# w: 200, b: 100

# %%
f_wb = compute_output(x_train, w, b,)

plt.plot(x_train, f_wb, c='b',label='Our Prediction')
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')
plt.title("Housing Prices")
plt.xlabel('Size (1000 sqft)')
plt.ylabel('Price (in 1000s USD)')
plt.legend()
plt.show()

# %%
w = 200
b = 100
x_i = 1.5
cost_1500_sqft = w * x_i + b

print(f"${cost_1500_sqft:.0f} thousand dollars")
# Out:
# $400 thousand dollars
